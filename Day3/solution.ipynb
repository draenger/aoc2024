# %% [markdown]
# --- Day 3: Mull It Over ---
#
# "Our computers are having issues, so I have no idea if we have any Chief Historians in stock! You're welcome to check the warehouse, though," says the mildly flustered shopkeeper at the North Pole Toboggan Rental Shop. The Historians head out to take a look.
#
# The shopkeeper turns to you. "Any chance you can see why our computers are having issues again?"
#
# The computer appears to be trying to run a program, but its memory (your puzzle input) is corrupted. All of the instructions have been jumbled up!
#
# It seems like the goal of the program is just to multiply some numbers. It does that with instructions like mul(X,Y), where X and Y are each 1-3 digit numbers. For instance, mul(44,46) multiplies 44 by 46 to get a result of 2024. Similarly, mul(123,4) would multiply 123 by 4.
#
# However, because the program's memory has been corrupted, there are also many invalid characters that should be ignored, even if they look like part of a mul instruction. Sequences like mul(4*, mul(6,9!, ?(12,34), or mul ( 2 , 4 ) do nothing.
#
# For example, consider the following section of corrupted memory:
#
# xmul(2,4)%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5))
#
# Only the four highlighted sections are real mul instructions. Adding up the result of each instruction produces 161 (2*4 + 5*5 + 11*8 + 8*5).
#
# Scan the corrupted memory for uncorrupted mul instructions. What do you get if you add up all of the results of the multiplications?

# %%
import re

class MultiplicationParser:
    def __init__(self):
        # Pattern matches 'mul' followed by 1-3 digits, comma, and 1-3 digits in parentheses
        self.pattern = r'mul\((\d{1,3}),(\d{1,3})\)'
        
    def process_file(self, file_path):
        try:
            with open(file_path, 'r') as file:
                content = file.read()
                print(content)
                return self.print_results(content)
        except FileNotFoundError:
            print(f"Błąd: Plik {file_path} nie został znaleziony.")
            return None
        except Exception as e:
            print(f"Wystąpił błąd podczas przetwarzania pliku: {str(e)}")
            return None
        
    def calculate_sum(self, text):
        # Find all matches in the text
        matches = re.finditer(self.pattern, text)
        
        total_sum = 0
        multiplications = []
        
        # Process each match
        for match in matches:
            num1 = int(match.group(1))
            num2 = int(match.group(2))
            result = num1 * num2
            multiplications.append((num1, num2, result))
            total_sum += result
            
        return {
            'multiplications': multiplications,
            'total_sum': total_sum
        }
    
    def print_results(self, text):
        results = self.calculate_sum(text)
        
        print("Znalezione mnożenia:")
        for num1, num2, result in results['multiplications']:
            print(f"{num1} * {num2} = {result}")
        
        print(f"\nSuma wszystkich iloczynów: {results['total_sum']}")
        return results['total_sum']
    
    # Przykład użycia
parser = MultiplicationParser()
text = "xmul(2,4)%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5))"
result = parser.print_results(text)
# Out:
# Znalezione mnożenia:
# 2 * 4 = 8
# 5 * 5 = 25
# 11 * 8 = 88
# 8 * 5 = 40
#
# Suma wszystkich iloczynów: 161

# %%
result = parser.process_file("input.txt")
# Out:
# ^+'*>,,why()mul(229,919)&$-#^~mul(187,600)@<select()mul(430,339)<)*/-when()%mul(248,922)~+when()<do()^}%where()@select() what()why()who(809,724)mul(617,192)$*from()what(168,899)mul(333,411)()$select(){+how()%mul(284,904)when();who()mul(218,212)>[#' *+&mul(388,743):~^&;do()when()&^&^mul(415,678)>what(180,378)when()/)!#how()~&do()(((]how()[~{;what()mul(792,328)[;(,why()#mul(767,729)(what()@-why()}who()how()where(373,159),mul(91,503)select()~;where()@+;;++don't()mul(766,411)~'&%what(217,603
(381,931)>>]select()+mul(451,520)don't()from()when(),<^-+mul(198,363)mul(469,259)?<how())+)mul(676,280)mul(631,824)~<)select()(what()who()-mul(270,524):mul(253,506))?{%}when()$*where(137,14)&mul(901,230)>@where()}~{select()-(<mul(353,334)?&when()^ #+where()~,mul(589,243)/*'where()what()^<+mul(668,536)/,@^--<( mul(221,71),when()'//(why()mul(822,686)+'%<where(),*@mul(208,127)#(<@},'-'mul(334,658))&* where()who()%from()mul(39,503)/+:how()'select()@mul(283,149)
#
# Znalezione mnożenia:
# 229 * 919 = 210451
# 187 * 600 = 112200
# 430 * 339 = 145770
# 248 * 922 = 228656
# 617 * 192 = 118464
# 333 * 411 = 136863
# 284 * 904 = 256736
# 218 * 212 = 46216
# 388 * 743 = 288284
# 415 * 678 = 281370
# 792 * 328 = 259776
# 767 * 729 = 559143
# 91 * 503 = 45773
# 766 * 411 = 314826
# 528 * 603 = 318384
# 418 * 950 = 397100
# 440 * 425 = 187000
# 42 * 798 = 33516
# 28 * 566 = 15848
# 167 * 358 = 59786
# 77 * 714 = 54978
# 748 * 367 = 274516
# 124 * 693 = 85932
# 121 * 164 = 19844
# 94 * 107 = 10058
# 51 * 763 = 38913
# 117 * 974 = 113958
# 224 * 518 = 116032
# 681 * 258 = 175698
# 301 * 302 = 90902
# 410 * 170 = 69700
# 873 * 748 = 653004
# 797 * 721 = 574637
# 959 * 163 = 156317
# 992 * 12 = 11904
# 141 * 535 = 75435
# 681 * 821 = 559101
# 123 * 886 = 108978
# 119 * 227 = 27013
# 525 * 607 = 318675
# 918 * 604 = 554472
# 138 * 66 = 9108
# 251 * 314 = 78814
# 843 * 719 = 606117
# 193 * 439 = 84727
# 677 * 473 = 320221
# 729 * 623 = 454167
# 496 * 695 = 344720
# 403 * 498 = 200694
# 723 * 890 = 643470
# 723 * 971 = 702033
# 805 * 935 = 752675
# 110 * 950 = 104500
# 161 * 461 = 74221
# 115 * 959 = 110285
# 816 * 844 = 688704
# 568 * 840 = 477120
# 601 * 790 = 474790
# 27 * 586 = 15822
# 425 * 554 = 235450
# 623 * 585 = 364455
# 995 * 90 = 89550
# 374 * 323 = 120802
# 249 * 230 = 57270
# 741 * 526 = 389766
# 373 * 937 = 349501
# 523 * 799 = 417877
# 438 * 812 = 355656
# 774 * 128 = 99072
# 376 * 393 = 147768
# 388 * 253 = 98164
# 37 * 722 = 26714
# 272 * 60 = 16320
# 301 * 857 = 257957
# 536 * 697 = 373592
# 806 * 354 = 285324
# 707 * 617 = 436219
# 475 * 36 = 17100
# 409 * 381 = 155829
# 106 * 765 = 81090
# 962 * 693 = 666666
# 838 * 166 = 139108
# 407 * 924 = 376068
# 305 * 306 = 93330
# 755 * 425 = 320875
# 119 * 487 = 57953
# 143 * 902 = 128986
# 378 * 307 = 116046
# 204 * 648 = 132192
# 812 * 89 = 72268
# 593 * 676 = 400868
# 561 * 33 = 18513
# 428 * 61 = 26108
# 116 * 657 = 76212
# 243 * 605 = 147015
# 85 * 278 = 23630
# 421 * 930 = 391530
# 325 * 145 = 47125
# 58 * 606 = 35148
# 563 * 278 = 156514
# 117 * 459 = 53703
# 473 * 512 = 242176
# 167 * 344 = 57448
# 508 * 557 = 282956
# 858 * 144 = 123552
# 332 * 118 = 39176
# 805 * 968 = 779240
# 31 * 7 = 217
# 790 * 338 = 267020
# 876 * 269 = 235644
# 705 * 526 = 370830
# 284 * 73 = 20732
# 336 * 280 = 94080
# 841 * 593 = 498713
# 611 * 712 = 435032
# 10 * 584 = 5840
# 776 * 536 = 415936
# 440 * 957 = 421080
# 282 * 762 = 214884
# 945 * 443 = 418635
# 174 * 224 = 38976
# 301 * 546 = 164346
# 180 * 572 = 102960
# 642 * 14 = 8988
# 711 * 95 = 67545
# 787 * 954 = 750798
# 449 * 665 = 298585
# 465 * 877 = 407805
# 908 * 857 = 778156
# 190 * 564 = 107160
# 539 * 109 = 58751
# 381 * 931 = 354711
# 451 * 520 = 234520
# 198 * 363 = 71874
# 469 * 259 = 121471
# 676 * 280 = 189280
# 631 * 824 = 519944
# 270 * 524 = 141480
# 253 * 506 = 128018
# 901 * 230 = 207230
# 353 * 334 = 117902
# 589 * 243 = 143127
# 668 * 536 = 358048
# 221 * 71 = 15691
# 822 * 686 = 563892
# 208 * 127 = 26416
# 334 * 658 = 219772
# 39 * 503 = 19617
# 283 * 149 = 42167
#
# Suma wszystkich iloczynów: 173785482

# %% [markdown]
# Your puzzle answer was 173785482.
#
# The first half of this puzzle is complete! It provides one gold star: *
# --- Part Two ---
#
# As you scan through the corrupted memory, you notice that some of the conditional statements are also still intact. If you handle some of the uncorrupted conditional statements in the program, you might be able to get an even more accurate result.
#
# There are two new instructions you'll need to handle:
#
#     The do() instruction enables future mul instructions.
#     The don't() instruction disables future mul instructions.
#
# Only the most recent do() or don't() instruction applies. At the beginning of the program, mul instructions are enabled.
#
# For example:
#
# xmul(2,4)&mul[3,7]!^don't()_mul(5,5)+mul(32,64](mul(11,8)undo()?mul(8,5))
#
# This corrupted memory is similar to the example from before, but this time the mul(5,5) and mul(11,8) instructions are disabled because there is a don't() instruction before them. The other mul instructions function normally, including the one at the end that gets re-enabled by a do() instruction.
#
# This time, the sum of the results is 48 (2*4 + 8*5).
#
# Handle the new instructions; what do you get if you add up all of the results of just the enabled multiplications?

# %%
import re

class MultiplicationParser:
    def __init__(self):
        # Pattern matches 'mul' followed by 1-3 digits, comma, and 1-3 digits in parentheses
        self.pattern = r'mul\((\d{1,3}),(\d{1,3})\)'
        self.do_pattern = r'do\(\)'
        self.dont_pattern = r'don\'t\(\)'
        
    def calculate_sum_with_conditions(self, text):
        # Find all matches for mul, do() and don't()
        mul_matches = [(m.start(), 'mul', m) for m in re.finditer(self.pattern, text)]
        do_matches = [(m.start(), 'do', m) for m in re.finditer(self.do_pattern, text)]
        dont_matches = [(m.start(), 'dont', m) for m in re.finditer(self.dont_pattern, text)]
        
        # Add virtual do() at position -1 (beginning of text)
        virtual_do = [(-1, 'do', None)]
        
        # Combine all matches and sort by position
        all_matches = sorted(virtual_do + mul_matches + do_matches + dont_matches, key=lambda x: x[0])
        
        print("Kolejność instrukcji:")
        for pos, type, _ in all_matches:
            print(f"Pozycja {pos}: {type}")
        
        total_sum = 0
        multiplications = []
        enabled = True  # At the beginning, mul instructions are enabled
        
        for pos, type, match in all_matches:
            if type == 'do':
                enabled = True
                print(f"Włączono mnożenia na pozycji {pos}")
            elif type == 'dont':
                enabled = False
                print(f"Wyłączono mnożenia na pozycji {pos}")
            elif type == 'mul' and enabled:
                num1 = int(match.group(1))
                num2 = int(match.group(2))
                result = num1 * num2
                multiplications.append((num1, num2, result, enabled))
                total_sum += result
                print(f"Mnożenie na pozycji {pos}: {num1} * {num2} = {result} (włączone)")
                
        return {
            'multiplications': multiplications,
            'total_sum': total_sum
        }
    
    def print_results_with_conditions(self, text):
        results = self.calculate_sum_with_conditions(text)
        
        print("\nZnalezione mnożenia (tylko włączone):")
        for num1, num2, result, enabled in results['multiplications']:
            print(f"{num1} * {num2} = {result} ({'włączone' if enabled else 'wyłączone'})")
        
        print(f"\nSuma wszystkich włączonych iloczynów: {results['total_sum']}")
        return results['total_sum']

    def process_file(self, file_path):
        try:
            with open(file_path, 'r') as file:
                content = file.read()
                return self.print_results_with_conditions(content)
        except FileNotFoundError:
            print(f"Błąd: Plik {file_path} nie został znaleziony.")
            return None
        except Exception as e:
            print(f"Wystąpił błąd podczas przetwarzania pliku: {str(e)}")
            return None
        
parser = MultiplicationParser()
text = "xmul(2,4)&mul[3,7]!^don't()_mul(5,5)+mul(32,64](mul(11,8)do()?mul(8,5))"
result = parser.print_results_with_conditions(text)
# Out:
# Kolejność instrukcji:
# Pozycja -1: do
# Pozycja 1: mul
# Pozycja 20: dont
# Pozycja 28: mul
# Pozycja 48: mul
# Pozycja 57: do
# Pozycja 62: mul
# Włączono mnożenia na pozycji -1
# Mnożenie na pozycji 1: 2 * 4 = 8 (włączone)
# Wyłączono mnożenia na pozycji 20
# Włączono mnożenia na pozycji 57
# Mnożenie na pozycji 62: 8 * 5 = 40 (włączone)
#
# Znalezione mnożenia (tylko włączone):
# 2 * 4 = 8 (włączone)
# 8 * 5 = 40 (włączone)
#
# Suma wszystkich włączonych iloczynów: 48

# %%
result = parser.process_file("input.txt")
# Out:
# Kolejność instrukcji:
# Pozycja -1: do
# Pozycja 12: mul
# Pozycja 30: mul
# Pozycja 52: mul
# Pozycja 76: mul
# Pozycja 97: do
# Pozycja 144: mul
# Pozycja 177: mul
# Pozycja 208: mul
# Pozycja 232: mul
# Pozycja 252: mul
# Pozycja 269: do
# Pozycja 283: mul
# Pozycja 326: do
# Pozycja 349: mul
# Pozycja 371: mul
# Pozycja 423: mul
# Pozycja 457: dont
# Pozycja 464: mul
# Pozycja 499: mul
# Pozycja 524: mul
# Pozycja 545: mul
# Pozycja 557: mul
# Pozycja 578: mul
# Pozycja 603: mul
# Pozycja 620: mul
# Pozycja 631: mul
# Pozycja 645: mul
# Pozycja 688: do
# Pozycja 695: mul
# Pozycja 720: mul
# Pozycja 770: mul
# Pozycja 785: mul
# Pozycja 809: mul
# Pozycja 827: mul
# Pozycja 865: mul
# Pozycja 878: dont
# Pozycja 900: mul
# Pozycja 912: do
# Pozycja 925: mul
# Pozycja 940: mul
# Pozycja 975: mul
# Pozycja 987: mul
# Pozycja 1008: mul
# Pozycja 1025: mul
# Pozycja 1046: mul
# Pozycja 1060: dont
# Pozycja 1070: mul
# Pozycja 1114: mul
# Pozycja 1129: mul
# Pozycja 1152: mul
# Pozycja 1175: mul
# Pozycja 1190: do
# Pozycja 1199: mul
# Pozycja 1212: mul
# Pozycja 1231: dont
# Pozycja 1241: mul
# Pozycja 1258: mul
# Pozycja 1292: mul
# Pozycja 1307: mul
# Pozycja 1319: mul
# Pozycja 1376: mul
# Pozycja 1388: mul
# Pozycja 1408: mul
# Pozycja 1421: mul
# Pozycja 1439: mul
# Pozycja 1469: mul
# Pozycja 1481: mul
# Pozycja 1494: do
# Pozycja 1506: mul
# Pozycja 1548: mul
# Pozycja 1585: mul
# Pozycja 1627: mul
# Pozycja 1646: mul
# Pozycja 1661: do
# Pozycja 1675: mul
# Pozycja 1687: mul
# Pozycja 1718: mul
# Pozycja 1733: mul
# Pozycja 1751: mul
# Pozycja 1763: mul
# Pozycja 1806: mul
# Pozycja 1839: mul
# Pozycja 1870: mul
# Pozycja 1896: mul
# Pozycja 1912: mul
# Pozycja 1929: mul
# Pozycja 1950: mul
# Pozycja 1972: mul
# Pozycja 2000: mul
# Pozycja 2044: mul
# Pozycja 2066: mul
# Pozycja 2087: do
# Pozycja 2093: mul
# Pozycja 2106: mul
# Pozycja 2160: mul
# Pozycja 2191: mul
# Pozycja 2203: mul
# Pozycja 2219: mul
# Pozycja 2233: dont
# Pozycja 2240: mul
# Pozycja 2253: mul
# Pozycja 2280: mul
# Pozycja 2294: mul
# Pozycja 2308: mul
# Pozycja 2341: mul
# Pozycja 2367: mul
# Pozycja 2379: do
# Pozycja 2403: mul
# Pozycja 2433: mul
# Pozycja 2446: mul
# Pozycja 2481: mul
# Pozycja 2513: mul
# Pozycja 2539: mul
# Pozycja 2568: mul
# Pozycja 2593: mul
# Pozycja 2620: mul
# Pozycja 2667: mul
# Pozycja 2708: dont
# Pozycja 2737: mul
# Pozycja 2751: mul
# Pozycja 2764: mul
# Pozycja 2786: mul
# Pozycja 2805: mul
# Pozycja 2828: mul
# Pozycja 2848: mul
# Pozycja 2877: mul
# Pozycja 2909: mul
# Pozycja 2928: do
# Pozycja 2947: mul
# Pozycja 2962: mul
# Pozycja 3015: mul
# Pozycja 3047: mul
# Pozycja 3071: mul
# Pozycja 3084: mul
# Pozycja 3095: mul
# Pozycja 3122: mul
# Pozycja 3149: mul
# Pozycja 3163: mul
# Pozycja 3188: mul
# Pozycja 3220: mul
# Pozycja 3241: mul
# Pozycja 3276: mul
# Pozycja 3314: mul
# Pozycja 3349: mul
# Pozycja 3374: mul
# Pozycja 3399: do
# Pozycja 3407: mul
# Pozycja 3424: mul
# Pozycja 3443: mul
# Pozycja 3469: mul
# Pozycja 3489: mul
# Pozycja 3523: mul
# Pozycja 3550: mul
# Pozycja 3576: mul
# Pozycja 3602: mul
# Pozycja 3638: mul
# Pozycja 3674: mul
# Pozycja 3704: mul
# Pozycja 3727: mul
# Pozycja 3758: mul
# Pozycja 3772: mul
# Pozycja 3785: mul
# Pozycja 3797: mul
# Pozycja 3810: mul
# Pozycja 3855: mul
# Pozycja 3872: mul
# Pozycja 3896: mul
# Pozycja 3932: mul
# Pozycja 3950: mul
# Pozycja 3969: mul
# Pozycja 4004: mul
# Pozycja 4032: mul
# Pozycja 4050: mul
# Pozycja 4083: mul
# Pozycja 4105: mul
# Pozycja 4124: mul
# Pozycja 4162: mul
# Pozycja 4188: mul
# Pozycja 4229: mul
# Pozycja 4242: mul
# Pozycja 4272: dont
# Pozycja 4286: mul
# Pozycja 4307: do
# Pozycja 4315: mul
# Pozycja 4355: mul
# Pozycja 4375: mul
# Pozycja 4406: mul
# Pozycja 4442: mul
# Pozycja 4465: mul
# Pozycja 4485: mul
# Pozycja 4503: mul
# Pozycja 4536: mul
# Pozycja 4549: do
# Pozycja 4553: mul
# Pozycja 4567: mul
# Pozycja 4594: mul
# Pozycja 4657: mul
# Pozycja 4687: do
# Pozycja 4691: mul
# Pozycja 4715: mul
# Pozycja 4755: mul
# Pozycja 4770: mul
# Pozycja 4804: do
# Pozycja 4823: mul
# Pozycja 4852: do
# Pozycja 4867: mul
# Pozycja 4878: mul
# Pozycja 4890: mul
# Pozycja 4919: mul
# Pozycja 4932: do
# Pozycja 4981: mul
# Pozycja 4995: mul
# Pozycja 5034: mul
# Pozycja 5075: mul
# Pozycja 5088: do
# Pozycja 5122: mul
# Pozycja 5174: mul
# Pozycja 5187: mul
# Pozycja 5255: mul
# Pozycja 5279: mul
# Pozycja 5312: mul
# Pozycja 5334: dont
# Pozycja 5353: mul
# Pozycja 5372: mul
# Pozycja 5398: mul
# Pozycja 5420: mul
# Pozycja 5456: mul
# Pozycja 5501: mul
# Pozycja 5511: mul
# Pozycja 5527: mul
# Pozycja 5567: mul
# Pozycja 5591: dont
# Pozycja 5623: mul
# Pozycja 5649: mul
# Pozycja 5666: mul
# Pozycja 5684: mul
# Pozycja 5723: mul
# Pozycja 5745: dont
# Pozycja 5761: mul
# Pozycja 5773: mul
# Pozycja 5785: mul
# Pozycja 5801: mul
# Pozycja 5827: mul
# Pozycja 5845: mul
# Pozycja 5871: mul
# Pozycja 5909: mul
# Pozycja 5924: mul
# Pozycja 5951: mul
# Pozycja 5976: mul
# Pozycja 5988: mul
# Pozycja 6024: mul
# Pozycja 6050: mul
# Pozycja 6074: dont
# Pozycja 6097: mul
# Pozycja 6133: mul
# Pozycja 6145: dont
# Pozycja 6178: mul
# Pozycja 6195: mul
# Pozycja 6217: mul
# Pozycja 6250: mul
# Pozycja 6272: mul
# Pozycja 6293: mul
# Pozycja 6307: dont
# Pozycja 6331: mul
# Pozycja 6386: mul
# Pozycja 6416: mul
# Pozycja 6450: mul
# Pozycja 6498: mul
# Pozycja 6515: do
# Pozycja 6542: mul
# Pozycja 6562: mul
# Pozycja 6574: dont
# Pozycja 6586: mul
# Pozycja 6599: mul
# Pozycja 6612: mul
# Pozycja 6637: mul
# Pozycja 6662: mul
# Pozycja 6689: mul
# Pozycja 6724: mul
# Pozycja 6736: mul
# Pozycja 6762: do
# Pozycja 6784: mul
# Pozycja 6812: mul
# Pozycja 6835: mul
# Pozycja 6871: mul
# Pozycja 6883: mul
# Pozycja 6903: mul
# Pozycja 6923: mul
# Pozycja 6957: mul
# Pozycja 7007: mul
# Pozycja 7027: mul
# Pozycja 7050: do
# Pozycja 7055: mul
# Pozycja 7080: mul
# Pozycja 7093: mul
# Pozycja 7115: dont
# Pozycja 7136: mul
# Pozycja 7158: mul
# Pozycja 7173: mul
# Pozycja 7215: mul
# Pozycja 7227: mul
# Pozycja 7248: do
# Pozycja 7258: mul
# Pozycja 7269: mul
# Pozycja 7297: mul
# Pozycja 7336: mul
# Pozycja 7362: mul
# Pozycja 7397: mul
# Pozycja 7409: mul
# Pozycja 7422: mul
# Pozycja 7441: mul
# Pozycja 7453: mul
# Pozycja 7489: do
# Pozycja 7498: mul
# Pozycja 7552: mul
# Pozycja 7602: mul
# Pozycja 7624: mul
# Pozycja 7636: mul
# Pozycja 7658: mul
# Pozycja 7671: mul
# Pozycja 7691: mul
# Pozycja 7727: mul
# Pozycja 7746: mul
# Pozycja 7759: mul
# Pozycja 7793: mul
# Pozycja 7828: mul
# Pozycja 7848: mul
# Pozycja 7900: mul
# Pozycja 7922: mul
# Pozycja 7946: mul
# Pozycja 7958: mul
# Pozycja 8007: mul
# Pozycja 8018: mul
# Pozycja 8062: mul
# Pozycja 8079: mul
# Pozycja 8096: mul
# Pozycja 8128: mul
# Pozycja 8140: mul
# Pozycja 8181: dont
# Pozycja 8198: mul
# Pozycja 8212: mul
# Pozycja 8238: mul
# Pozycja 8254: mul
# Pozycja 8268: mul
# Pozycja 8293: mul
# Pozycja 8305: mul
# Pozycja 8338: mul
# Pozycja 8351: mul
# Pozycja 8364: mul
# Pozycja 8375: mul
# Pozycja 8407: mul
# Pozycja 8419: mul
# Pozycja 8451: mul
# Pozycja 8479: mul
# Pozycja 8495: mul
# Pozycja 8507: mul
# Pozycja 8519: mul
# Pozycja 8555: mul
# Pozycja 8572: mul
# Pozycja 8604: mul
# Pozycja 8627: mul
# Pozycja 8684: mul
# Pozycja 8712: mul
# Pozycja 8748: dont
# Pozycja 8757: mul
# Pozycja 8799: mul
# Pozycja 8844: dont
# Pozycja 8873: mul
# Pozycja 8934: mul
# Pozycja 8962: mul
# Pozycja 8975: mul
# Pozycja 8998: mul
# Pozycja 9036: mul
# Pozycja 9048: mul
# Pozycja 9093: mul
# Pozycja 9116: mul
# Pozycja 9132: mul
# Pozycja 9146: do
# Pozycja 9166: mul
# Pozycja 9187: mul
# Pozycja 9211: mul
# Pozycja 9236: mul
# Pozycja 9248: mul
# Pozycja 9274: mul
# Pozycja 9308: mul
# Pozycja 9350: mul
# Pozycja 9365: mul
# Pozycja 9380: mul
# Pozycja 9408: mul
# Pozycja 9422: mul
# Pozycja 9477: mul
# Pozycja 9505: mul
# Pozycja 9525: mul
# Pozycja 9543: mul
# Pozycja 9562: mul
# Pozycja 9576: dont
# Pozycja 9591: mul
# Pozycja 9615: mul
# Pozycja 9637: mul
# Pozycja 9668: mul
# Pozycja 9686: mul
# Pozycja 9709: mul
# Pozycja 9746: mul
# Pozycja 9768: mul
# Pozycja 9781: mul
# Pozycja 9801: mul
# Pozycja 9813: mul
# Pozycja 9826: mul
# Pozycja 9856: mul
# Pozycja 9869: mul
# Pozycja 9892: mul
# Pozycja 9918: mul
# Pozycja 9933: mul
# Pozycja 9955: mul
# Pozycja 9980: mul
# Pozycja 10016: mul
# Pozycja 10069: mul
# Pozycja 10101: mul
# Pozycja 10122: mul
# Pozycja 10134: mul
# Pozycja 10210: mul
# Pozycja 10224: mul
# Pozycja 10253: mul
# Pozycja 10274: mul
# Pozycja 10298: mul
# Pozycja 10312: mul
# Pozycja 10325: mul
# Pozycja 10366: mul
# Pozycja 10380: mul
# Pozycja 10418: mul
# Pozycja 10474: mul
# Pozycja 10506: mul
# Pozycja 10523: mul
# Pozycja 10550: mul
# Pozycja 10567: mul
# Pozycja 10593: mul
# Pozycja 10606: mul
# Pozycja 10625: dont
# Pozycja 10657: mul
# Pozycja 10723: mul
# Pozycja 10740: mul
# Pozycja 10773: mul
# Pozycja 10797: do
# Pozycja 10808: mul
# Pozycja 10852: mul
# Pozycja 10864: dont
# Pozycja 10881: mul
# Pozycja 10894: mul
# Pozycja 10907: mul
# Pozycja 10933: mul
# Pozycja 10964: mul
# Pozycja 11014: mul
# Pozycja 11050: mul
# Pozycja 11064: mul
# Pozycja 11088: mul
# Pozycja 11111: mul
# Pozycja 11148: mul
# Pozycja 11191: mul
# Pozycja 11224: mul
# Pozycja 11238: mul
# Pozycja 11272: mul
# Pozycja 11307: mul
# Pozycja 11346: mul
# Pozycja 11360: mul
# Pozycja 11372: mul
# Pozycja 11390: mul
# Pozycja 11421: mul
# Pozycja 11465: mul
# Pozycja 11485: mul
# Pozycja 11508: mul
# Pozycja 11530: mul
# Pozycja 11553: mul
# Pozycja 11564: mul
# Pozycja 11600: mul
# Pozycja 11645: mul
# Pozycja 11661: mul
# Pozycja 11681: mul
# Pozycja 11700: mul
# Pozycja 11714: mul
# Pozycja 11755: mul
# Pozycja 11791: mul
# Pozycja 11812: mul
# Pozycja 11830: mul
# Pozycja 11844: mul
# Pozycja 11863: mul
# Pozycja 11895: mul
# Pozycja 11918: mul
# Pozycja 11932: mul
# Pozycja 11951: mul
# Pozycja 11978: mul
# Pozycja 12004: mul
# Pozycja 12046: mul
# Pozycja 12070: mul
# Pozycja 12087: mul
# Pozycja 12108: mul
# Pozycja 12180: mul
# Pozycja 12205: mul
# Pozycja 12224: do
# Pozycja 12232: mul
# Pozycja 12255: mul
# Pozycja 12288: mul
# Pozycja 12309: mul
# Pozycja 12326: mul
# Pozycja 12339: mul
# Pozycja 12362: do
# Pozycja 12372: mul
# Pozycja 12391: mul
# Pozycja 12449: dont
# Pozycja 12456: mul
# Pozycja 12490: mul
# Pozycja 12503: mul
# Pozycja 12515: mul
# Pozycja 12529: mul
# Pozycja 12543: mul
# Pozycja 12572: mul
# Pozycja 12599: mul
# Pozycja 12643: mul
# Pozycja 12677: mul
# Pozycja 12689: mul
# Pozycja 12736: dont
# Pozycja 12757: mul
# Pozycja 12773: mul
# Pozycja 12794: mul
# Pozycja 12826: mul
# Pozycja 12850: mul
# Pozycja 12891: mul
# Pozycja 12921: mul
# Pozycja 12933: mul
# Pozycja 12945: mul
# Pozycja 12958: mul
# Pozycja 12997: mul
# Pozycja 13018: mul
# Pozycja 13042: mul
# Pozycja 13085: mul
# Pozycja 13121: mul
# Pozycja 13146: mul
# Pozycja 13160: dont
# Pozycja 13199: mul
# Pozycja 13210: mul
# Pozycja 13238: mul
# Pozycja 13252: mul
# Pozycja 13264: do
# Pozycja 13286: mul
# Pozycja 13320: mul
# Pozycja 13355: mul
# Pozycja 13371: mul
# Pozycja 13395: mul
# Pozycja 13412: mul
# Pozycja 13431: mul
# Pozycja 13470: mul
# Pozycja 13496: mul
# Pozycja 13521: mul
# Pozycja 13561: mul
# Pozycja 13591: mul
# Pozycja 13604: mul
# Pozycja 13617: mul
# Pozycja 13641: mul
# Pozycja 13660: dont
# Pozycja 13708: mul
# Pozycja 13733: mul
# Pozycja 13756: mul
# Pozycja 13795: mul
# Pozycja 13808: mul
# Pozycja 13828: mul
# Pozycja 13859: mul
# Pozycja 13900: do
# Pozycja 13918: mul
# Pozycja 13946: mul
# Pozycja 13974: mul
# Pozycja 14015: mul
# Pozycja 14081: mul
# Pozycja 14108: mul
# Pozycja 14148: mul
# Pozycja 14163: mul
# Pozycja 14196: mul
# Pozycja 14233: mul
# Pozycja 14260: mul
# Pozycja 14272: mul
# Pozycja 14287: mul
# Pozycja 14325: dont
# Pozycja 14358: mul
# Pozycja 14384: mul
# Pozycja 14415: mul
# Pozycja 14427: do
# Pozycja 14438: mul
# Pozycja 14466: mul
# Pozycja 14493: mul
# Pozycja 14522: mul
# Pozycja 14547: mul
# Pozycja 14580: mul
# Pozycja 14605: mul
# Pozycja 14622: mul
# Pozycja 14637: dont
# Pozycja 14657: mul
# Pozycja 14699: mul
# Pozycja 14717: mul
# Pozycja 14729: mul
# Pozycja 14763: mul
# Pozycja 14790: mul
# Pozycja 14809: mul
# Pozycja 14827: do
# Pozycja 14846: mul
# Pozycja 14874: mul
# Pozycja 14900: mul
# Pozycja 14941: mul
# Pozycja 14965: mul
# Pozycja 14996: mul
# Pozycja 15012: mul
# Pozycja 15028: mul
# Pozycja 15039: mul
# Pozycja 15051: do
# Pozycja 15075: mul
# Pozycja 15111: mul
# Pozycja 15148: do
# Pozycja 15172: mul
# Pozycja 15244: mul
# Pozycja 15270: mul
# Pozycja 15295: mul
# Pozycja 15347: mul
# Pozycja 15369: mul
# Pozycja 15397: mul
# Pozycja 15416: mul
# Pozycja 15448: mul
# Pozycja 15481: mul
# Pozycja 15517: mul
# Pozycja 15560: mul
# Pozycja 15583: dont
# Pozycja 15620: mul
# Pozycja 15647: mul
# Pozycja 15684: mul
# Pozycja 15723: mul
# Pozycja 15740: mul
# Pozycja 15754: mul
# Pozycja 15781: mul
# Pozycja 15818: mul
# Pozycja 15837: mul
# Pozycja 15870: mul
# Pozycja 15888: mul
# Pozycja 15919: mul
# Pozycja 15963: mul
# Pozycja 15979: mul
# Pozycja 16000: mul
# Pozycja 16044: mul
# Pozycja 16128: mul
# Pozycja 16149: mul
# Pozycja 16161: mul
# Pozycja 16191: mul
# Pozycja 16226: mul
# Pozycja 16278: dont
# Pozycja 16294: mul
# Pozycja 16318: mul
# Pozycja 16334: mul
# Pozycja 16346: mul
# Pozycja 16359: dont
# Pozycja 16366: mul
# Pozycja 16379: mul
# Pozycja 16418: mul
# Pozycja 16452: mul
# Pozycja 16480: mul
# Pozycja 16525: do
# Pozycja 16536: mul
# Pozycja 16556: mul
# Pozycja 16570: mul
# Pozycja 16599: mul
# Pozycja 16613: mul
# Pozycja 16636: dont
# Pozycja 16656: mul
# Pozycja 16703: mul
# Pozycja 16735: mul
# Pozycja 16749: mul
# Pozycja 16798: mul
# Pozycja 16818: mul
# Pozycja 16831: mul
# Pozycja 16860: mul
# Pozycja 16873: dont
# Pozycja 16892: mul
# Pozycja 16903: mul
# Pozycja 16928: mul
# Pozycja 16942: mul
# Pozycja 16957: mul
# Pozycja 16988: mul
# Pozycja 17025: mul
# Pozycja 17037: mul
# Pozycja 17057: mul
# Pozycja 17090: mul
# Pozycja 17116: mul
# Pozycja 17130: mul
# Pozycja 17154: mul
# Pozycja 17174: mul
# Pozycja 17186: mul
# Pozycja 17200: mul
# Pozycja 17239: do
# Pozycja 17243: mul
# Pozycja 17258: mul
# Pozycja 17274: mul
# Pozycja 17322: dont
# Pozycja 17330: mul
# Pozycja 17348: mul
# Pozycja 17365: mul
# Pozycja 17377: mul
# Pozycja 17389: mul
# Pozycja 17405: mul
# Pozycja 17425: mul
# Pozycja 17439: dont
# Pozycja 17446: mul
# Pozycja 17465: mul
# Pozycja 17477: dont
# Pozycja 17491: mul
# Pozycja 17510: mul
# Pozycja 17539: mul
# Pozycja 17553: mul
# Pozycja 17578: mul
# Pozycja 17603: mul
# Pozycja 17629: mul
# Pozycja 17649: mul
# Pozycja 17682: mul
# Pozycja 17710: mul
# Pozycja 17748: dont
# Pozycja 17761: mul
# Pozycja 17808: mul
# Pozycja 17820: mul
# Pozycja 17852: mul
# Pozycja 17886: dont
# Pozycja 17893: mul
# Pozycja 17914: dont
# Pozycja 17921: mul
# Pozycja 17944: mul
# Pozycja 17980: mul
# Pozycja 18005: mul
# Pozycja 18018: mul
# Pozycja 18045: mul
# Pozycja 18071: mul
# Pozycja 18095: mul
# Pozycja 18107: mul
# Pozycja 18172: mul
# Pozycja 18204: mul
# Pozycja 18222: do
# Pozycja 18240: mul
# Pozycja 18253: mul
# Pozycja 18281: mul
# Pozycja 18323: mul
# Pozycja 18351: mul
# Pozycja 18364: mul
# Pozycja 18391: mul
# Pozycja 18415: mul
# Pozycja 18440: mul
# Pozycja 18481: mul
# Pozycja 18506: mul
# Pozycja 18521: mul
# Pozycja 18559: mul
# Pozycja 18574: mul
# Pozycja 18594: mul
# Pozycja 18622: mul
# Pozycja 18636: mul
# Pozycja 18672: mul
# Pozycja 18704: mul
# Pozycja 18724: mul
# Pozycja 18736: mul
# Pozycja 18748: mul
# Pozycja 18767: mul
# Pozycja 18803: mul
# Pozycja 18816: mul
# Pozycja 18844: mul
# Pozycja 18858: mul
# Pozycja 18883: mul
# Pozycja 18902: mul
# Pozycja 18922: mul
# Pozycja 18960: mul
# Pozycja 19013: mul
# Pozycja 19052: mul
# Pozycja 19077: mul
# Pozycja 19091: mul
# Pozycja 19130: mul
# Pozycja 19178: mul
# Pozycja 19216: mul
# Pozycja 19228: do
# Pozycja 19264: mul
# Pozycja 19296: mul
# Pozycja 19321: mul
# Pozycja 19333: mul
# Pozycja 19354: mul
# Pozycja 19388: mul
# Pozycja 19401: mul
# Pozycja 19427: mul
# Pozycja 19442: mul
# Pozycja 19456: mul
# Pozycja 19482: mul
# Pozycja 19498: mul
# Pozycja 19527: do
# Pozycja 19537: mul
# Pozycja 19574: mul
# Pozycja 19589: mul
# Pozycja 19619: mul
# Pozycja 19650: mul
# Pozycja 19673: mul
# Pozycja 19707: mul
# Pozycja 19719: mul
# Pozycja 19744: mul
# Pozycja 19778: mul
# Pozycja 19808: mul
# Pozycja 19827: mul
# Pozycja 19847: mul
# Pozycja 19877: mul
# Pozycja 19893: mul
# Pozycja 19918: mul
# Pozycja 19948: mul
# Pozycja 19972: mul
# Pozycja 19984: dont
# Pozycja 20008: mul
# Pozycja 20020: mul
# Pozycja 20042: mul
# Pozycja 20054: mul
# Pozycja 20090: mul
# Pozycja 20103: mul
# Pozycja 20142: mul
# Pozycja 20177: mul
# Pozycja 20210: mul
# Pozycja 20241: mul
# Pozycja 20262: mul
# Pozycja 20289: mul
# Pozycja 20315: mul
# Pozycja 20336: mul
# Pozycja 20371: mul
# Pozycja 20400: mul
# Włączono mnożenia na pozycji -1
# Mnożenie na pozycji 12: 229 * 919 = 210451 (włączone)
# Mnożenie na pozycji 30: 187 * 600 = 112200 (włączone)
# Mnożenie na pozycji 52: 430 * 339 = 145770 (włączone)
# Mnożenie na pozycji 76: 248 * 922 = 228656 (włączone)
# Włączono mnożenia na pozycji 97
# Mnożenie na pozycji 144: 617 * 192 = 118464 (włączone)
# Mnożenie na pozycji 177: 333 * 411 = 136863 (włączone)
# Mnożenie na pozycji 208: 284 * 904 = 256736 (włączone)
# Mnożenie na pozycji 232: 218 * 212 = 46216 (włączone)
# Mnożenie na pozycji 252: 388 * 743 = 288284 (włączone)
# Włączono mnożenia na pozycji 269
# Mnożenie na pozycji 283: 415 * 678 = 281370 (włączone)
# Włączono mnożenia na pozycji 326
# Mnożenie na pozycji 349: 792 * 328 = 259776 (włączone)
# Mnożenie na pozycji 371: 767 * 729 = 559143 (włączone)
# Mnożenie na pozycji 423: 91 * 503 = 45773 (włączone)
# Wyłączono mnożenia na pozycji 457
# Włączono mnożenia na pozycji 688
# Mnożenie na pozycji 695: 121 * 164 = 19844 (włączone)
# Mnożenie na pozycji 720: 94 * 107 = 10058 (włączone)
# Mnożenie na pozycji 770: 51 * 763 = 38913 (włączone)
# Mnożenie na pozycji 785: 117 * 974 = 113958 (włączone)
# Mnożenie na pozycji 809: 224 * 518 = 116032 (włączone)
# Mnożenie na pozycji 827: 681 * 258 = 175698 (włączone)
# Mnożenie na pozycji 865: 301 * 302 = 90902 (włączone)
# Wyłączono mnożenia na pozycji 878
# Włączono mnożenia na pozycji 912
# Mnożenie na pozycji 925: 873 * 748 = 653004 (włączone)
# Mnożenie na pozycji 940: 797 * 721 = 574637 (włączone)
# Mnożenie na pozycji 975: 959 * 163 = 156317 (włączone)
# Mnożenie na pozycji 987: 992 * 12 = 11904 (włączone)
# Mnożenie na pozycji 1008: 141 * 535 = 75435 (włączone)
# Mnożenie na pozycji 1025: 681 * 821 = 559101 (włączone)
# Mnożenie na pozycji 1046: 123 * 886 = 108978 (włączone)
# Wyłączono mnożenia na pozycji 1060
# Włączono mnożenia na pozycji 1190
# Mnożenie na pozycji 1199: 843 * 719 = 606117 (włączone)
# Mnożenie na pozycji 1212: 193 * 439 = 84727 (włączone)
# Wyłączono mnożenia na pozycji 1231
# Włączono mnożenia na pozycji 1494
# Mnożenie na pozycji 1506: 601 * 790 = 474790 (włączone)
# Mnożenie na pozycji 1548: 27 * 586 = 15822 (włączone)
# Mnożenie na pozycji 1585: 425 * 554 = 235450 (włączone)
# Mnożenie na pozycji 1627: 623 * 585 = 364455 (włączone)
# Mnożenie na pozycji 1646: 995 * 90 = 89550 (włączone)
# Włączono mnożenia na pozycji 1661
# Mnożenie na pozycji 1675: 374 * 323 = 120802 (włączone)
# Mnożenie na pozycji 1687: 249 * 230 = 57270 (włączone)
# Mnożenie na pozycji 1718: 741 * 526 = 389766 (włączone)
# Mnożenie na pozycji 1733: 373 * 937 = 349501 (włączone)
# Mnożenie na pozycji 1751: 523 * 799 = 417877 (włączone)
# Mnożenie na pozycji 1763: 438 * 812 = 355656 (włączone)
# Mnożenie na pozycji 1806: 774 * 128 = 99072 (włączone)
# Mnożenie na pozycji 1839: 376 * 393 = 147768 (włączone)
# Mnożenie na pozycji 1870: 388 * 253 = 98164 (włączone)
# Mnożenie na pozycji 1896: 37 * 722 = 26714 (włączone)
# Mnożenie na pozycji 1912: 272 * 60 = 16320 (włączone)
# Mnożenie na pozycji 1929: 301 * 857 = 257957 (włączone)
# Mnożenie na pozycji 1950: 536 * 697 = 373592 (włączone)
# Mnożenie na pozycji 1972: 806 * 354 = 285324 (włączone)
# Mnożenie na pozycji 2000: 707 * 617 = 436219 (włączone)
# Mnożenie na pozycji 2044: 475 * 36 = 17100 (włączone)
# Mnożenie na pozycji 2066: 409 * 381 = 155829 (włączone)
# Włączono mnożenia na pozycji 2087
# Mnożenie na pozycji 2093: 106 * 765 = 81090 (włączone)
# Mnożenie na pozycji 2106: 962 * 693 = 666666 (włączone)
# Mnożenie na pozycji 2160: 838 * 166 = 139108 (włączone)
# Mnożenie na pozycji 2191: 407 * 924 = 376068 (włączone)
# Mnożenie na pozycji 2203: 305 * 306 = 93330 (włączone)
# Mnożenie na pozycji 2219: 755 * 425 = 320875 (włączone)
# Wyłączono mnożenia na pozycji 2233
# Włączono mnożenia na pozycji 2379
# Mnożenie na pozycji 2403: 428 * 61 = 26108 (włączone)
# Mnożenie na pozycji 2433: 116 * 657 = 76212 (włączone)
# Mnożenie na pozycji 2446: 243 * 605 = 147015 (włączone)
# Mnożenie na pozycji 2481: 85 * 278 = 23630 (włączone)
# Mnożenie na pozycji 2513: 421 * 930 = 391530 (włączone)
# Mnożenie na pozycji 2539: 325 * 145 = 47125 (włączone)
# Mnożenie na pozycji 2568: 242 * 136 = 32912 (włączone)
# Mnożenie na pozycji 2593: 223 * 291 = 64893 (włączone)
# Mnożenie na pozycji 2620: 280 * 922 = 258160 (włączone)
# Mnożenie na pozycji 2667: 136 * 869 = 118184 (włączone)
# Wyłączono mnożenia na pozycji 2708
# Włączono mnożenia na pozycji 2928
# Mnożenie na pozycji 2947: 859 * 153 = 131427 (włączone)
# Mnożenie na pozycji 2962: 968 * 909 = 879912 (włączone)
# Mnożenie na pozycji 3015: 164 * 591 = 96924 (włączone)
# Mnożenie na pozycji 3047: 198 * 449 = 88902 (włączone)
# Mnożenie na pozycji 3071: 549 * 221 = 121329 (włączone)
# Mnożenie na pozycji 3084: 10 * 487 = 4870 (włączone)
# Mnożenie na pozycji 3095: 473 * 495 = 234135 (włączone)
# Mnożenie na pozycji 3122: 409 * 356 = 145604 (włączone)
# Mnożenie na pozycji 3149: 245 * 522 = 127890 (włączone)
# Mnożenie na pozycji 3163: 830 * 352 = 292160 (włączone)
# Mnożenie na pozycji 3188: 348 * 779 = 271092 (włączone)
# Mnożenie na pozycji 3220: 631 * 610 = 384910 (włączone)
# Mnożenie na pozycji 3241: 364 * 859 = 312676 (włączone)
# Mnożenie na pozycji 3276: 381 * 350 = 133350 (włączone)
# Mnożenie na pozycji 3314: 832 * 589 = 490048 (włączone)
# Mnożenie na pozycji 3349: 315 * 787 = 247905 (włączone)
# Mnożenie na pozycji 3374: 331 * 479 = 158549 (włączone)
# Włączono mnożenia na pozycji 3399
# Mnożenie na pozycji 3407: 693 * 126 = 87318 (włączone)
# Mnożenie na pozycji 3424: 969 * 600 = 581400 (włączone)
# Mnożenie na pozycji 3443: 214 * 616 = 131824 (włączone)
# Mnożenie na pozycji 3469: 855 * 428 = 365940 (włączone)
# Mnożenie na pozycji 3489: 334 * 489 = 163326 (włączone)
# Mnożenie na pozycji 3523: 110 * 881 = 96910 (włączone)
# Mnożenie na pozycji 3550: 138 * 273 = 37674 (włączone)
# Mnożenie na pozycji 3576: 749 * 786 = 588714 (włączone)
# Mnożenie na pozycji 3602: 179 * 995 = 178105 (włączone)
# Mnożenie na pozycji 3638: 475 * 52 = 24700 (włączone)
# Mnożenie na pozycji 3674: 75 * 799 = 59925 (włączone)
# Mnożenie na pozycji 3704: 700 * 332 = 232400 (włączone)
# Mnożenie na pozycji 3727: 942 * 3 = 2826 (włączone)
# Mnożenie na pozycji 3758: 987 * 195 = 192465 (włączone)
# Mnożenie na pozycji 3772: 901 * 207 = 186507 (włączone)
# Mnożenie na pozycji 3785: 887 * 450 = 399150 (włączone)
# Mnożenie na pozycji 3797: 302 * 276 = 83352 (włączone)
# Mnożenie na pozycji 3810: 705 * 411 = 289755 (włączone)
# Mnożenie na pozycji 3855: 812 * 264 = 214368 (włączone)
# Mnożenie na pozycji 3872: 170 * 516 = 87720 (włączone)
# Mnożenie na pozycji 3896: 41 * 851 = 34891 (włączone)
# Mnożenie na pozycji 3932: 10 * 905 = 9050 (włączone)
# Mnożenie na pozycji 3950: 479 * 534 = 255786 (włączone)
# Mnożenie na pozycji 3969: 251 * 951 = 238701 (włączone)
# Mnożenie na pozycji 4004: 143 * 289 = 41327 (włączone)
# Mnożenie na pozycji 4032: 766 * 808 = 618928 (włączone)
# Mnożenie na pozycji 4050: 358 * 761 = 272438 (włączone)
# Mnożenie na pozycji 4083: 170 * 223 = 37910 (włączone)
# Mnożenie na pozycji 4105: 990 * 347 = 343530 (włączone)
# Mnożenie na pozycji 4124: 346 * 803 = 277838 (włączone)
# Mnożenie na pozycji 4162: 972 * 647 = 628884 (włączone)
# Mnożenie na pozycji 4188: 113 * 574 = 64862 (włączone)
# Mnożenie na pozycji 4229: 540 * 811 = 437940 (włączone)
# Mnożenie na pozycji 4242: 384 * 379 = 145536 (włączone)
# Wyłączono mnożenia na pozycji 4272
# Włączono mnożenia na pozycji 4307
# Mnożenie na pozycji 4315: 836 * 469 = 392084 (włączone)
# Mnożenie na pozycji 4355: 888 * 841 = 746808 (włączone)
# Mnożenie na pozycji 4375: 696 * 36 = 25056 (włączone)
# Mnożenie na pozycji 4406: 458 * 301 = 137858 (włączone)
# Mnożenie na pozycji 4442: 575 * 266 = 152950 (włączone)
# Mnożenie na pozycji 4465: 731 * 33 = 24123 (włączone)
# Mnożenie na pozycji 4485: 53 * 430 = 22790 (włączone)
# Mnożenie na pozycji 4503: 586 * 117 = 68562 (włączone)
# Mnożenie na pozycji 4536: 229 * 295 = 67555 (włączone)
# Włączono mnożenia na pozycji 4549
# Mnożenie na pozycji 4553: 993 * 128 = 127104 (włączone)
# Mnożenie na pozycji 4567: 853 * 954 = 813762 (włączone)
# Mnożenie na pozycji 4594: 941 * 420 = 395220 (włączone)
# Mnożenie na pozycji 4657: 537 * 993 = 533241 (włączone)
# Włączono mnożenia na pozycji 4687
# Mnożenie na pozycji 4691: 794 * 923 = 732862 (włączone)
# Mnożenie na pozycji 4715: 805 * 982 = 790510 (włączone)
# Mnożenie na pozycji 4755: 638 * 751 = 479138 (włączone)
# Mnożenie na pozycji 4770: 443 * 735 = 325605 (włączone)
# Włączono mnożenia na pozycji 4804
# Mnożenie na pozycji 4823: 272 * 487 = 132464 (włączone)
# Włączono mnożenia na pozycji 4852
# Mnożenie na pozycji 4867: 28 * 452 = 12656 (włączone)
# Mnożenie na pozycji 4878: 178 * 145 = 25810 (włączone)
# Mnożenie na pozycji 4890: 396 * 673 = 266508 (włączone)
# Mnożenie na pozycji 4919: 648 * 926 = 600048 (włączone)
# Włączono mnożenia na pozycji 4932
# Mnożenie na pozycji 4981: 340 * 339 = 115260 (włączone)
# Mnożenie na pozycji 4995: 358 * 858 = 307164 (włączone)
# Mnożenie na pozycji 5034: 642 * 325 = 208650 (włączone)
# Mnożenie na pozycji 5075: 532 * 676 = 359632 (włączone)
# Włączono mnożenia na pozycji 5088
# Mnożenie na pozycji 5122: 162 * 432 = 69984 (włączone)
# Mnożenie na pozycji 5174: 747 * 115 = 85905 (włączone)
# Mnożenie na pozycji 5187: 525 * 823 = 432075 (włączone)
# Mnożenie na pozycji 5255: 541 * 522 = 282402 (włączone)
# Mnożenie na pozycji 5279: 6 * 198 = 1188 (włączone)
# Mnożenie na pozycji 5312: 677 * 201 = 136077 (włączone)
# Wyłączono mnożenia na pozycji 5334
# Wyłączono mnożenia na pozycji 5591
# Wyłączono mnożenia na pozycji 5745
# Wyłączono mnożenia na pozycji 6074
# Wyłączono mnożenia na pozycji 6145
# Wyłączono mnożenia na pozycji 6307
# Włączono mnożenia na pozycji 6515
# Mnożenie na pozycji 6542: 421 * 915 = 385215 (włączone)
# Mnożenie na pozycji 6562: 143 * 731 = 104533 (włączone)
# Wyłączono mnożenia na pozycji 6574
# Włączono mnożenia na pozycji 6762
# Mnożenie na pozycji 6784: 695 * 556 = 386420 (włączone)
# Mnożenie na pozycji 6812: 870 * 233 = 202710 (włączone)
# Mnożenie na pozycji 6835: 90 * 29 = 2610 (włączone)
# Mnożenie na pozycji 6871: 880 * 98 = 86240 (włączone)
# Mnożenie na pozycji 6883: 64 * 639 = 40896 (włączone)
# Mnożenie na pozycji 6903: 244 * 640 = 156160 (włączone)
# Mnożenie na pozycji 6923: 262 * 110 = 28820 (włączone)
# Mnożenie na pozycji 6957: 733 * 807 = 591531 (włączone)
# Mnożenie na pozycji 7007: 210 * 195 = 40950 (włączone)
# Mnożenie na pozycji 7027: 397 * 920 = 365240 (włączone)
# Włączono mnożenia na pozycji 7050
# Mnożenie na pozycji 7055: 773 * 279 = 215667 (włączone)
# Mnożenie na pozycji 7080: 643 * 570 = 366510 (włączone)
# Mnożenie na pozycji 7093: 105 * 506 = 53130 (włączone)
# Wyłączono mnożenia na pozycji 7115
# Włączono mnożenia na pozycji 7248
# Mnożenie na pozycji 7258: 15 * 142 = 2130 (włączone)
# Mnożenie na pozycji 7269: 876 * 153 = 134028 (włączone)
# Mnożenie na pozycji 7297: 664 * 520 = 345280 (włączone)
# Mnożenie na pozycji 7336: 785 * 595 = 467075 (włączone)
# Mnożenie na pozycji 7362: 888 * 328 = 291264 (włączone)
# Mnożenie na pozycji 7397: 633 * 692 = 438036 (włączone)
# Mnożenie na pozycji 7409: 173 * 839 = 145147 (włączone)
# Mnożenie na pozycji 7422: 204 * 278 = 56712 (włączone)
# Mnożenie na pozycji 7441: 451 * 395 = 178145 (włączone)
# Mnożenie na pozycji 7453: 785 * 151 = 118535 (włączone)
# Włączono mnożenia na pozycji 7489
# Mnożenie na pozycji 7498: 790 * 654 = 516660 (włączone)
# Mnożenie na pozycji 7552: 806 * 984 = 793104 (włączone)
# Mnożenie na pozycji 7602: 861 * 224 = 192864 (włączone)
# Mnożenie na pozycji 7624: 899 * 370 = 332630 (włączone)
# Mnożenie na pozycji 7636: 549 * 105 = 57645 (włączone)
# Mnożenie na pozycji 7658: 725 * 344 = 249400 (włączone)
# Mnożenie na pozycji 7671: 41 * 164 = 6724 (włączone)
# Mnożenie na pozycji 7691: 955 * 760 = 725800 (włączone)
# Mnożenie na pozycji 7727: 50 * 448 = 22400 (włączone)
# Mnożenie na pozycji 7746: 315 * 814 = 256410 (włączone)
# Mnożenie na pozycji 7759: 194 * 503 = 97582 (włączone)
# Mnożenie na pozycji 7793: 223 * 541 = 120643 (włączone)
# Mnożenie na pozycji 7828: 364 * 778 = 283192 (włączone)
# Mnożenie na pozycji 7848: 47 * 912 = 42864 (włączone)
# Mnożenie na pozycji 7900: 693 * 8 = 5544 (włączone)
# Mnożenie na pozycji 7922: 528 * 520 = 274560 (włączone)
# Mnożenie na pozycji 7946: 401 * 20 = 8020 (włączone)
# Mnożenie na pozycji 7958: 274 * 431 = 118094 (włączone)
# Mnożenie na pozycji 8007: 733 * 66 = 48378 (włączone)
# Mnożenie na pozycji 8018: 463 * 265 = 122695 (włączone)
# Mnożenie na pozycji 8062: 225 * 388 = 87300 (włączone)
# Mnożenie na pozycji 8079: 593 * 40 = 23720 (włączone)
# Mnożenie na pozycji 8096: 773 * 292 = 225716 (włączone)
# Mnożenie na pozycji 8128: 910 * 722 = 657020 (włączone)
# Mnożenie na pozycji 8140: 983 * 696 = 684168 (włączone)
# Wyłączono mnożenia na pozycji 8181
# Wyłączono mnożenia na pozycji 8748
# Wyłączono mnożenia na pozycji 8844
# Włączono mnożenia na pozycji 9146
# Mnożenie na pozycji 9166: 448 * 64 = 28672 (włączone)
# Mnożenie na pozycji 9187: 679 * 387 = 262773 (włączone)
# Mnożenie na pozycji 9211: 486 * 701 = 340686 (włączone)
# Mnożenie na pozycji 9236: 559 * 794 = 443846 (włączone)
# Mnożenie na pozycji 9248: 627 * 726 = 455202 (włączone)
# Mnożenie na pozycji 9274: 550 * 422 = 232100 (włączone)
# Mnożenie na pozycji 9308: 500 * 999 = 499500 (włączone)
# Mnożenie na pozycji 9350: 890 * 188 = 167320 (włączone)
# Mnożenie na pozycji 9365: 669 * 810 = 541890 (włączone)
# Mnożenie na pozycji 9380: 760 * 372 = 282720 (włączone)
# Mnożenie na pozycji 9408: 141 * 133 = 18753 (włączone)
# Mnożenie na pozycji 9422: 339 * 807 = 273573 (włączone)
# Mnożenie na pozycji 9477: 243 * 407 = 98901 (włączone)
# Mnożenie na pozycji 9505: 741 * 399 = 295659 (włączone)
# Mnożenie na pozycji 9525: 457 * 257 = 117449 (włączone)
# Mnożenie na pozycji 9543: 471 * 231 = 108801 (włączone)
# Mnożenie na pozycji 9562: 641 * 452 = 289732 (włączone)
# Wyłączono mnożenia na pozycji 9576
# Wyłączono mnożenia na pozycji 10625
# Włączono mnożenia na pozycji 10797
# Mnożenie na pozycji 10808: 756 * 84 = 63504 (włączone)
# Mnożenie na pozycji 10852: 767 * 508 = 389636 (włączone)
# Wyłączono mnożenia na pozycji 10864
# Włączono mnożenia na pozycji 12224
# Mnożenie na pozycji 12232: 937 * 389 = 364493 (włączone)
# Mnożenie na pozycji 12255: 7 * 641 = 4487 (włączone)
# Mnożenie na pozycji 12288: 604 * 895 = 540580 (włączone)
# Mnożenie na pozycji 12309: 762 * 876 = 667512 (włączone)
# Mnożenie na pozycji 12326: 953 * 72 = 68616 (włączone)
# Mnożenie na pozycji 12339: 771 * 143 = 110253 (włączone)
# Włączono mnożenia na pozycji 12362
# Mnożenie na pozycji 12372: 127 * 841 = 106807 (włączone)
# Mnożenie na pozycji 12391: 324 * 780 = 252720 (włączone)
# Wyłączono mnożenia na pozycji 12449
# Wyłączono mnożenia na pozycji 12736
# Wyłączono mnożenia na pozycji 13160
# Włączono mnożenia na pozycji 13264
# Mnożenie na pozycji 13286: 790 * 845 = 667550 (włączone)
# Mnożenie na pozycji 13320: 181 * 583 = 105523 (włączone)
# Mnożenie na pozycji 13355: 532 * 225 = 119700 (włączone)
# Mnożenie na pozycji 13371: 510 * 91 = 46410 (włączone)
# Mnożenie na pozycji 13395: 193 * 421 = 81253 (włączone)
# Mnożenie na pozycji 13412: 421 * 747 = 314487 (włączone)
# Mnożenie na pozycji 13431: 542 * 99 = 53658 (włączone)
# Mnożenie na pozycji 13470: 200 * 487 = 97400 (włączone)
# Mnożenie na pozycji 13496: 689 * 957 = 659373 (włączone)
# Mnożenie na pozycji 13521: 12 * 272 = 3264 (włączone)
# Mnożenie na pozycji 13561: 501 * 743 = 372243 (włączone)
# Mnożenie na pozycji 13591: 455 * 700 = 318500 (włączone)
# Mnożenie na pozycji 13604: 39 * 833 = 32487 (włączone)
# Mnożenie na pozycji 13617: 804 * 222 = 178488 (włączone)
# Mnożenie na pozycji 13641: 45 * 702 = 31590 (włączone)
# Wyłączono mnożenia na pozycji 13660
# Włączono mnożenia na pozycji 13900
# Mnożenie na pozycji 13918: 342 * 700 = 239400 (włączone)
# Mnożenie na pozycji 13946: 333 * 963 = 320679 (włączone)
# Mnożenie na pozycji 13974: 947 * 945 = 894915 (włączone)
# Mnożenie na pozycji 14015: 494 * 61 = 30134 (włączone)
# Mnożenie na pozycji 14081: 842 * 681 = 573402 (włączone)
# Mnożenie na pozycji 14108: 535 * 168 = 89880 (włączone)
# Mnożenie na pozycji 14148: 926 * 493 = 456518 (włączone)
# Mnożenie na pozycji 14163: 150 * 741 = 111150 (włączone)
# Mnożenie na pozycji 14196: 56 * 868 = 48608 (włączone)
# Mnożenie na pozycji 14233: 747 * 999 = 746253 (włączone)
# Mnożenie na pozycji 14260: 175 * 156 = 27300 (włączone)
# Mnożenie na pozycji 14272: 884 * 607 = 536588 (włączone)
# Mnożenie na pozycji 14287: 998 * 216 = 215568 (włączone)
# Wyłączono mnożenia na pozycji 14325
# Włączono mnożenia na pozycji 14427
# Mnożenie na pozycji 14438: 849 * 72 = 61128 (włączone)
# Mnożenie na pozycji 14466: 186 * 911 = 169446 (włączone)
# Mnożenie na pozycji 14493: 679 * 485 = 329315 (włączone)
# Mnożenie na pozycji 14522: 426 * 354 = 150804 (włączone)
# Mnożenie na pozycji 14547: 287 * 918 = 263466 (włączone)
# Mnożenie na pozycji 14580: 449 * 449 = 201601 (włączone)
# Mnożenie na pozycji 14605: 24 * 301 = 7224 (włączone)
# Mnożenie na pozycji 14622: 753 * 855 = 643815 (włączone)
# Wyłączono mnożenia na pozycji 14637
# Włączono mnożenia na pozycji 14827
# Mnożenie na pozycji 14846: 944 * 864 = 815616 (włączone)
# Mnożenie na pozycji 14874: 5 * 629 = 3145 (włączone)
# Mnożenie na pozycji 14900: 544 * 161 = 87584 (włączone)
# Mnożenie na pozycji 14941: 693 * 695 = 481635 (włączone)
# Mnożenie na pozycji 14965: 201 * 445 = 89445 (włączone)
# Mnożenie na pozycji 14996: 65 * 416 = 27040 (włączone)
# Mnożenie na pozycji 15012: 632 * 729 = 460728 (włączone)
# Mnożenie na pozycji 15028: 18 * 292 = 5256 (włączone)
# Mnożenie na pozycji 15039: 87 * 905 = 78735 (włączone)
# Włączono mnożenia na pozycji 15051
# Mnożenie na pozycji 15075: 292 * 732 = 213744 (włączone)
# Mnożenie na pozycji 15111: 577 * 286 = 165022 (włączone)
# Włączono mnożenia na pozycji 15148
# Mnożenie na pozycji 15172: 62 * 435 = 26970 (włączone)
# Mnożenie na pozycji 15244: 298 * 421 = 125458 (włączone)
# Mnożenie na pozycji 15270: 593 * 593 = 351649 (włączone)
# Mnożenie na pozycji 15295: 826 * 174 = 143724 (włączone)
# Mnożenie na pozycji 15347: 128 * 77 = 9856 (włączone)
# Mnożenie na pozycji 15369: 576 * 352 = 202752 (włączone)
# Mnożenie na pozycji 15397: 288 * 458 = 131904 (włączone)
# Mnożenie na pozycji 15416: 39 * 137 = 5343 (włączone)
# Mnożenie na pozycji 15448: 638 * 58 = 37004 (włączone)
# Mnożenie na pozycji 15481: 605 * 171 = 103455 (włączone)
# Mnożenie na pozycji 15517: 178 * 672 = 119616 (włączone)
# Mnożenie na pozycji 15560: 671 * 276 = 185196 (włączone)
# Wyłączono mnożenia na pozycji 15583
# Wyłączono mnożenia na pozycji 16278
# Wyłączono mnożenia na pozycji 16359
# Włączono mnożenia na pozycji 16525
# Mnożenie na pozycji 16536: 292 * 571 = 166732 (włączone)
# Mnożenie na pozycji 16556: 854 * 593 = 506422 (włączone)
# Mnożenie na pozycji 16570: 93 * 255 = 23715 (włączone)
# Mnożenie na pozycji 16599: 139 * 648 = 90072 (włączone)
# Mnożenie na pozycji 16613: 805 * 139 = 111895 (włączone)
# Wyłączono mnożenia na pozycji 16636
# Wyłączono mnożenia na pozycji 16873
# Włączono mnożenia na pozycji 17239
# Mnożenie na pozycji 17243: 892 * 588 = 524496 (włączone)
# Mnożenie na pozycji 17258: 4 * 214 = 856 (włączone)
# Mnożenie na pozycji 17274: 802 * 248 = 198896 (włączone)
# Wyłączono mnożenia na pozycji 17322
# Wyłączono mnożenia na pozycji 17439
# Wyłączono mnożenia na pozycji 17477
# Wyłączono mnożenia na pozycji 17748
# Wyłączono mnożenia na pozycji 17886
# Wyłączono mnożenia na pozycji 17914
# Włączono mnożenia na pozycji 18222
# Mnożenie na pozycji 18240: 245 * 72 = 17640 (włączone)
# Mnożenie na pozycji 18253: 262 * 717 = 187854 (włączone)
# Mnożenie na pozycji 18281: 806 * 380 = 306280 (włączone)
# Mnożenie na pozycji 18323: 954 * 891 = 850014 (włączone)
# Mnożenie na pozycji 18351: 52 * 145 = 7540 (włączone)
# Mnożenie na pozycji 18364: 645 * 872 = 562440 (włączone)
# Mnożenie na pozycji 18391: 255 * 174 = 44370 (włączone)
# Mnożenie na pozycji 18415: 839 * 305 = 255895 (włączone)
# Mnożenie na pozycji 18440: 572 * 454 = 259688 (włączone)
# Mnożenie na pozycji 18481: 341 * 203 = 69223 (włączone)
# Mnożenie na pozycji 18506: 116 * 924 = 107184 (włączone)
# Mnożenie na pozycji 18521: 536 * 362 = 194032 (włączone)
# Mnożenie na pozycji 18559: 674 * 414 = 279036 (włączone)
# Mnożenie na pozycji 18574: 499 * 509 = 253991 (włączone)
# Mnożenie na pozycji 18594: 125 * 544 = 68000 (włączone)
# Mnożenie na pozycji 18622: 694 * 107 = 74258 (włączone)
# Mnożenie na pozycji 18636: 589 * 269 = 158441 (włączone)
# Mnożenie na pozycji 18672: 779 * 394 = 306926 (włączone)
# Mnożenie na pozycji 18704: 418 * 402 = 168036 (włączone)
# Mnożenie na pozycji 18724: 771 * 556 = 428676 (włączone)
# Mnożenie na pozycji 18736: 48 * 471 = 22608 (włączone)
# Mnożenie na pozycji 18748: 5 * 471 = 2355 (włączone)
# Mnożenie na pozycji 18767: 584 * 991 = 578744 (włączone)
# Mnożenie na pozycji 18803: 662 * 976 = 646112 (włączone)
# Mnożenie na pozycji 18816: 378 * 372 = 140616 (włączone)
# Mnożenie na pozycji 18844: 693 * 943 = 653499 (włączone)
# Mnożenie na pozycji 18858: 71 * 492 = 34932 (włączone)
# Mnożenie na pozycji 18883: 325 * 434 = 141050 (włączone)
# Mnożenie na pozycji 18902: 39 * 981 = 38259 (włączone)
# Mnożenie na pozycji 18922: 962 * 307 = 295334 (włączone)
# Mnożenie na pozycji 18960: 442 * 854 = 377468 (włączone)
# Mnożenie na pozycji 19013: 138 * 127 = 17526 (włączone)
# Mnożenie na pozycji 19052: 74 * 742 = 54908 (włączone)
# Mnożenie na pozycji 19077: 58 * 606 = 35148 (włączone)
# Mnożenie na pozycji 19091: 563 * 278 = 156514 (włączone)
# Mnożenie na pozycji 19130: 117 * 459 = 53703 (włączone)
# Mnożenie na pozycji 19178: 473 * 512 = 242176 (włączone)
# Mnożenie na pozycji 19216: 167 * 344 = 57448 (włączone)
# Włączono mnożenia na pozycji 19228
# Mnożenie na pozycji 19264: 508 * 557 = 282956 (włączone)
# Mnożenie na pozycji 19296: 858 * 144 = 123552 (włączone)
# Mnożenie na pozycji 19321: 332 * 118 = 39176 (włączone)
# Mnożenie na pozycji 19333: 805 * 968 = 779240 (włączone)
# Mnożenie na pozycji 19354: 31 * 7 = 217 (włączone)
# Mnożenie na pozycji 19388: 790 * 338 = 267020 (włączone)
# Mnożenie na pozycji 19401: 876 * 269 = 235644 (włączone)
# Mnożenie na pozycji 19427: 705 * 526 = 370830 (włączone)
# Mnożenie na pozycji 19442: 284 * 73 = 20732 (włączone)
# Mnożenie na pozycji 19456: 336 * 280 = 94080 (włączone)
# Mnożenie na pozycji 19482: 841 * 593 = 498713 (włączone)
# Mnożenie na pozycji 19498: 611 * 712 = 435032 (włączone)
# Włączono mnożenia na pozycji 19527
# Mnożenie na pozycji 19537: 10 * 584 = 5840 (włączone)
# Mnożenie na pozycji 19574: 776 * 536 = 415936 (włączone)
# Mnożenie na pozycji 19589: 440 * 957 = 421080 (włączone)
# Mnożenie na pozycji 19619: 282 * 762 = 214884 (włączone)
# Mnożenie na pozycji 19650: 945 * 443 = 418635 (włączone)
# Mnożenie na pozycji 19673: 174 * 224 = 38976 (włączone)
# Mnożenie na pozycji 19707: 301 * 546 = 164346 (włączone)
# Mnożenie na pozycji 19719: 180 * 572 = 102960 (włączone)
# Mnożenie na pozycji 19744: 642 * 14 = 8988 (włączone)
# Mnożenie na pozycji 19778: 711 * 95 = 67545 (włączone)
# Mnożenie na pozycji 19808: 787 * 954 = 750798 (włączone)
# Mnożenie na pozycji 19827: 449 * 665 = 298585 (włączone)
# Mnożenie na pozycji 19847: 465 * 877 = 407805 (włączone)
# Mnożenie na pozycji 19877: 908 * 857 = 778156 (włączone)
# Mnożenie na pozycji 19893: 190 * 564 = 107160 (włączone)
# Mnożenie na pozycji 19918: 539 * 109 = 58751 (włączone)
# Mnożenie na pozycji 19948: 381 * 931 = 354711 (włączone)
# Mnożenie na pozycji 19972: 451 * 520 = 234520 (włączone)
# Wyłączono mnożenia na pozycji 19984
#
# Znalezione mnożenia (tylko włączone):
# 229 * 919 = 210451 (włączone)
# 187 * 600 = 112200 (włączone)
# 430 * 339 = 145770 (włączone)
# 248 * 922 = 228656 (włączone)
# 617 * 192 = 118464 (włączone)
# 333 * 411 = 136863 (włączone)
# 284 * 904 = 256736 (włączone)
# 218 * 212 = 46216 (włączone)
# 388 * 743 = 288284 (włączone)
# 415 * 678 = 281370 (włączone)
# 792 * 328 = 259776 (włączone)
# 767 * 729 = 559143 (włączone)
# 91 * 503 = 45773 (włączone)
# 121 * 164 = 19844 (włączone)
# 94 * 107 = 10058 (włączone)
# 51 * 763 = 38913 (włączone)
# 117 * 974 = 113958 (włączone)
# 224 * 518 = 116032 (włączone)
# 681 * 258 = 175698 (włączone)
# 301 * 302 = 90902 (włączone)
# 873 * 748 = 653004 (włączone)
# 797 * 721 = 574637 (włączone)
# 959 * 163 = 156317 (włączone)
# 992 * 12 = 11904 (włączone)
# 141 * 535 = 75435 (włączone)
# 681 * 821 = 559101 (włączone)
# 123 * 886 = 108978 (włączone)
# 843 * 719 = 606117 (włączone)
# 193 * 439 = 84727 (włączone)
# 601 * 790 = 474790 (włączone)
# 27 * 586 = 15822 (włączone)
# 425 * 554 = 235450 (włączone)
# 623 * 585 = 364455 (włączone)
# 995 * 90 = 89550 (włączone)
# 374 * 323 = 120802 (włączone)
# 249 * 230 = 57270 (włączone)
# 741 * 526 = 389766 (włączone)
# 373 * 937 = 349501 (włączone)
# 523 * 799 = 417877 (włączone)
# 178 * 672 = 119616 (włączone)
# 671 * 276 = 185196 (włączone)
# 292 * 571 = 166732 (włączone)
# 854 * 593 = 506422 (włączone)
# 93 * 255 = 23715 (włączone)
# 139 * 648 = 90072 (włączone)
# 805 * 139 = 111895 (włączone)
# 892 * 588 = 524496 (włączone)
# 4 * 214 = 856 (włączone)
# 802 * 248 = 198896 (włączone)
# 245 * 72 = 17640 (włączone)
# 262 * 717 = 187854 (włączone)
# 806 * 380 = 306280 (włączone)
# 954 * 891 = 850014 (włączone)
# 52 * 145 = 7540 (włączone)
# 645 * 872 = 562440 (włączone)
# 255 * 174 = 44370 (włączone)
# 839 * 305 = 255895 (włączone)
# 572 * 454 = 259688 (włączone)
# 341 * 203 = 69223 (włączone)
# 116 * 924 = 107184 (włączone)
# 536 * 362 = 194032 (włączone)
# 674 * 414 = 279036 (włączone)
# 499 * 509 = 253991 (włączone)
# 125 * 544 = 68000 (włączone)
# 694 * 107 = 74258 (włączone)
# 589 * 269 = 158441 (włączone)
# 779 * 394 = 306926 (włączone)
# 418 * 402 = 168036 (włączone)
# 771 * 556 = 428676 (włączone)
# 48 * 471 = 22608 (włączone)
# 5 * 471 = 2355 (włączone)
# 584 * 991 = 578744 (włączone)
# 662 * 976 = 646112 (włączone)
# 378 * 372 = 140616 (włączone)
# 693 * 943 = 653499 (włączone)
# 71 * 492 = 34932 (włączone)
# 325 * 434 = 141050 (włączone)
# 39 * 981 = 38259 (włączone)
# 962 * 307 = 295334 (włączone)
# 442 * 854 = 377468 (włączone)
# 138 * 127 = 17526 (włączone)
# 74 * 742 = 54908 (włączone)
# 58 * 606 = 35148 (włączone)
# 563 * 278 = 156514 (włączone)
# 117 * 459 = 53703 (włączone)
# 473 * 512 = 242176 (włączone)
# 167 * 344 = 57448 (włączone)
# 508 * 557 = 282956 (włączone)
# 858 * 144 = 123552 (włączone)
# 332 * 118 = 39176 (włączone)
# 805 * 968 = 779240 (włączone)
# 31 * 7 = 217 (włączone)
# 790 * 338 = 267020 (włączone)
# 876 * 269 = 235644 (włączone)
# 705 * 526 = 370830 (włączone)
# 284 * 73 = 20732 (włączone)
# 336 * 280 = 94080 (włączone)
# 841 * 593 = 498713 (włączone)
# 611 * 712 = 435032 (włączone)
# 10 * 584 = 5840 (włączone)
# 776 * 536 = 415936 (włączone)
# 440 * 957 = 421080 (włączone)
# 282 * 762 = 214884 (włączone)
# 945 * 443 = 418635 (włączone)
# 174 * 224 = 38976 (włączone)
# 301 * 546 = 164346 (włączone)
# 180 * 572 = 102960 (włączone)
# 642 * 14 = 8988 (włączone)
# 711 * 95 = 67545 (włączone)
# 787 * 954 = 750798 (włączone)
# 449 * 665 = 298585 (włączone)
# 465 * 877 = 407805 (włączone)
# 908 * 857 = 778156 (włączone)
# 190 * 564 = 107160 (włączone)
# 539 * 109 = 58751 (włączone)
# 381 * 931 = 354711 (włączone)
# 451 * 520 = 234520 (włączone)
#
# Suma wszystkich włączonych iloczynów: 83158140

# %% [markdown]
# Your puzzle answer was 83158140.
#
# Both parts of this puzzle are complete! They provide two gold stars: **
